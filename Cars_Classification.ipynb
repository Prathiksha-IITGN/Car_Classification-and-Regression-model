# %% [markdown]
# #Problem Formulation: To find the class of the car
# Y(dependent variable) -class of cars
# Classification problem

# %%
#Load the dataset
import pandas as pd
df=pd.read_csv("cars_class.csv")

# %%
display(df)
# Out:
#       ID  Comp  Circ  D.Circ  Rad.Ra  Pr.Axis.Ra  Max.L.Ra  Scat.Ra  Elong  \
# 0      1    88    39      70     166          66         7      148     44
# 1      2    85    35      64     129          57         6      116     57
# 2      3    91    41      84     141          57         9      149     45
# 3      4   102    54      98     177          56        10      219     31
# 4      5    87    39      74     152          58         6      151     44
# ..   ...   ...   ...     ...     ...         ...       ...      ...    ...
# 714  715   111    58     105     183          51         6      265     26
# 715  716    93    43      76     149          57         7      149     44
# 716  717    90    42      63     144          59         7      131     50
# 717  718   101    56     101     231          72        10      217     31
# 718  719    99    38      74     184          66         6      164     39
#
# ...

# %%
df.head(5)
# Out:
#    ID  Comp  Circ  D.Circ  Rad.Ra  Pr.Axis.Ra  Max.L.Ra  Scat.Ra  Elong  \
# 0   1    88    39      70     166          66         7      148     44
# 1   2    85    35      64     129          57         6      116     57
# 2   3    91    41      84     141          57         9      149     45
# 3   4   102    54      98     177          56        10      219     31
# 4   5    87    39      74     152          58         6      151     44
#
#    Pr.Axis.Rect  Max.L.Rect  Sc.Var.Maxis  Sc.Var.maxis  Ra.Gyr  Skew.Maxis  \
# 0            19         134           167           332     143          69
# 1            17         125           138           200     123          65
# 2            19         143           170           330     158          72
# 3            25         171           219           706     223          72
# 4            19         136           174           337     140          70
#
#    Skew.maxis  Kurt.maxis  Kurt.Maxis  Holl.Ra  Class
# ...

# %%
df.describe()
# Out:
#                ID        Comp        Circ      D.Circ      Rad.Ra  Pr.Axis.Ra  \
# count  719.000000  719.000000  719.000000  719.000000  719.000000  719.000000
# mean   360.000000   93.435327   44.851182   81.723227  168.579972   61.847010
# std    207.701709    8.111406    6.150286   15.528208   33.809172    8.259136
# min      1.000000   73.000000   33.000000   40.000000  105.000000   47.000000
# 25%    180.500000   87.000000   40.000000   70.000000  141.000000   57.000000
# 50%    360.000000   93.000000   44.000000   79.000000  166.000000   61.000000
# 75%    539.500000   99.000000   49.000000   96.000000  194.500000   65.000000
# max    719.000000  119.000000   59.000000  110.000000  333.000000  138.000000
#
#          Max.L.Ra     Scat.Ra       Elong  Pr.Axis.Rect  Max.L.Rect  \
# count  719.000000  719.000000  719.000000    719.000000  719.000000
# mean     8.625869  168.137691   41.075104     20.531293  148.030598
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Comp', 'Circ', 'D.Circ', 'Rad.Ra', 'Pr.Axis.Ra', 'Max.L.Ra',
#        'Scat.Ra', 'Elong', 'Pr.Axis.Rect', 'Max.L.Rect', 'Sc.Var.Maxis',
#        'Sc.Var.maxis', 'Ra.Gyr', 'Skew.Maxis', 'Skew.maxis', 'Kurt.maxis',
#        'Kurt.Maxis', 'Holl.Ra', 'Class'],
#       dtype='object')

# %%
df.shape
# Out:
# (719, 20)

# %%
#To check unique values:

for col in df.columns:
    print(col,df[col].nunique())
# Out:
# ID 719
# Comp 43
# Circ 27
# D.Circ 60
# Rad.Ra 132
# Pr.Axis.Ra 37
# Max.L.Ra 21
# Scat.Ra 125
# Elong 35
# Pr.Axis.Rect 13
# Max.L.Rect 66
# Sc.Var.Maxis 124
# Sc.Var.maxis 380
# Ra.Gyr 138
# Skew.Maxis 39
# Skew.maxis 23
# Kurt.maxis 38
# Kurt.Maxis 29
# Holl.Ra 31
# Class 4

# %%
#Distribution of each features:

for col in df.columns:
    print(col,df[col].value_counts())
# Out:
# ID 1      1
# 495    1
# 475    1
# 476    1
# 477    1
#       ..
# 242    1
# 243    1
# 244    1
# 245    1
# 719    1
# Name: ID, Length: 719, dtype: int64
# Comp 89     52
# 86     42
# 93     40
# 85     36
# 91     36
# 90     36
# 94     29
# 97     27
# 98     26
# 88     26
# 87     26
# 96     25
# 100    24
# 95     22
# 104    21
# 84     20
# 101    19
# 92     19
# 82     17
# 106    16
# 102    16
# 105    15
# 83     15
# 107    15
# 103    14
# 99     14
# 108    13
# 81     11
# 109    10
# 80      9
# 79      5
# 78      4
# 111     4
# 110     3
# 113     3
# 77      2
# 117     1
# 112     1
# 115     1
# 119     1
# 73      1
# 114     1
# 76      1
# Name: Comp, dtype: int64
# Circ 43    52
# 44    46
# 45    46
# 46    44
# 38    41
# 42    38
# 36    37
# 39    35
# 37    35
# 40    35
# 47    33
# 54    32
# 55    32
# 41    31
# 48    26
# 49    24
# 52    24
# 51    23
# 53    21
# 35    14
# 50    13
# 56    13
# 57    12
# 34     6
# 58     4
# ...

# %%
#split dependent and independent:

y = df['Class']
X = df.drop('Class', axis = 1)

# %%
y
# Out:
# 0      0
# 1      3
# 2      3
# 3      1
# 4      2
#       ..
# 714    0
# 715    2
# 716    3
# 717    2
# 718    0
# Name: Class, Length: 719, dtype: int64

# %%
X
# Out:
#       ID  Comp  Circ  D.Circ  Rad.Ra  Pr.Axis.Ra  Max.L.Ra  Scat.Ra  Elong  \
# 0      1    88    39      70     166          66         7      148     44
# 1      2    85    35      64     129          57         6      116     57
# 2      3    91    41      84     141          57         9      149     45
# 3      4   102    54      98     177          56        10      219     31
# 4      5    87    39      74     152          58         6      151     44
# ..   ...   ...   ...     ...     ...         ...       ...      ...    ...
# 714  715   111    58     105     183          51         6      265     26
# 715  716    93    43      76     149          57         7      149     44
# 716  717    90    42      63     144          59         7      131     50
# 717  718   101    56     101     231          72        10      217     31
# 718  719    99    38      74     184          66         6      164     39
#
# ...

# %%
#split train_test:

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state=1)

# %% [markdown]
# # EDA

# %%
#missing value:
X_train.isnull().sum()
# Out:
# ID              0
# Comp            0
# Circ            0
# D.Circ          0
# Rad.Ra          0
# Pr.Axis.Ra      0
# Max.L.Ra        0
# Scat.Ra         0
# Elong           0
# Pr.Axis.Rect    0
# Max.L.Rect      0
# Sc.Var.Maxis    0
# Sc.Var.maxis    0
# Ra.Gyr          0
# Skew.Maxis      0
# Skew.maxis      0
# Kurt.maxis      0
# Kurt.Maxis      0
# Holl.Ra         0
# dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 575 entries, 34 to 37
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            575 non-null    int64
#  1   Comp          575 non-null    int64
#  2   Circ          575 non-null    int64
#  3   D.Circ        575 non-null    int64
#  4   Rad.Ra        575 non-null    int64
#  5   Pr.Axis.Ra    575 non-null    int64
#  6   Max.L.Ra      575 non-null    int64
#  7   Scat.Ra       575 non-null    int64
#  8   Elong         575 non-null    int64
#  9   Pr.Axis.Rect  575 non-null    int64
#  10  Max.L.Rect    575 non-null    int64
#  11  Sc.Var.Maxis  575 non-null    int64
#  12  Sc.Var.maxis  575 non-null    int64
#  13  Ra.Gyr        575 non-null    int64
#  14  Skew.Maxis    575 non-null    int64
#  15  Skew.maxis    575 non-null    int64
#  16  Kurt.maxis    575 non-null    int64
#  17  Kurt.Maxis    575 non-null    int64
# ...

# %%
X_train.dtypes
# Out:
# ID              int64
# Comp            int64
# Circ            int64
# D.Circ          int64
# Rad.Ra          int64
# Pr.Axis.Ra      int64
# Max.L.Ra        int64
# Scat.Ra         int64
# Elong           int64
# Pr.Axis.Rect    int64
# Max.L.Rect      int64
# Sc.Var.Maxis    int64
# Sc.Var.maxis    int64
# Ra.Gyr          int64
# Skew.Maxis      int64
# Skew.maxis      int64
# Kurt.maxis      int64
# Kurt.Maxis      int64
# Holl.Ra         int64
# dtype: object

# %%
#scaling
import seaborn as sns

# %%
sns.boxplot(data=X_train)
# Out:
# <AxesSubplot: >

# %%
from sklearn.preprocessing import StandardScaler

# %%
SC=StandardScaler()
X_train=SC.fit_transform(X_train)

# %%
X_test=SC.transform(X_test)

# %%
sns.boxplot(data=X_train)
# Out:
# <AxesSubplot: >

# %%
# Assuming you have a DataFrame called df
df['column_name'] = df['column_name'].astype(int)

# %%
#Models:

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

# %%
#Model Evaluation:
from sklearn.metrics import f1_score,confusion_matrix

# %%
#Logisticregression:

LR=LogisticRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# C:\ZEN ANACONDA\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LR.score(X_test,y_test)
# Out:
# 0.7916666666666666

# %%
y_pred = LR.predict(X_test)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)

# Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# F1 score (micro-averaging): 0.7916666666666666
# F1 score (macro-averaging): 0.7638535054922762
# F1 score (weighted-averaging): 0.7820872359730395
# Confusion Matrix:
# [[43  0  0  1]
#  [ 3 14 11  2]
#  [ 1  9 24  1]
#  [ 2  0  0 33]]

# %%
#KNN:

KNN=KNeighborsClassifier()
KNN.fit(X_train,y_train)
print(KNN.score(X_test,y_test))
y_pred = KNN.predict(X_test)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)

# Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# 0.7291666666666666
# F1 score (micro-averaging): 0.7291666666666665
# F1 score (macro-averaging): 0.7004307390135077
# F1 score (weighted-averaging): 0.7224744128881534
# Confusion Matrix:
# [[42  0  0  2]
#  [ 3 13 12  2]
#  [ 1 14 19  1]
#  [ 2  1  1 31]]
# C:\ZEN ANACONDA\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
#svc

svc=SVC()
svc.fit(X_train,y_train)
print(svc.score(X_test,y_test))
y_pred=svc.predict(X_test)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)

# Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# 0.7430555555555556
# F1 score (micro-averaging): 0.7430555555555556
# F1 score (macro-averaging): 0.706335585340162
# F1 score (weighted-averaging): 0.7293008588298443
# Confusion Matrix:
# [[43  0  0  1]
#  [ 3 13 11  3]
#  [ 1 14 17  3]
#  [ 1  0  0 34]]

# %%
#DTC(Decision Tree Classifier)
DTC=KNeighborsClassifier()
DTC.fit(X_train,y_train)
print(DTC.score(X_test,y_test))
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)
# Out:
# 0.7291666666666666
# F1 score (micro-averaging): 0.7430555555555556
# F1 score (macro-averaging): 0.706335585340162
# F1 score (weighted-averaging): 0.7293008588298443
# C:\ZEN ANACONDA\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
#RandomForestClassifier
RFC=RandomForestClassifier()
RFC.fit(X_train,y_train)
print(RFC.score(X_test,y_test))
y_pred=RFC.predict(X_test)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)

# Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# 0.7361111111111112
# F1 score (micro-averaging): 0.7361111111111113
# F1 score (macro-averaging): 0.6979632505948296
# F1 score (weighted-averaging): 0.7243950599213757
# Confusion Matrix:
# [[44  0  0  0]
#  [ 1 12 15  2]
#  [ 1 15 16  3]
#  [ 1  0  0 34]]

# %%
#AdaBoostClassifier
ABC=AdaBoostClassifier()
ABC.fit(X_train,y_train)
print(ABC.score(X_test,y_test))
y_pred=ABC.predict(X_test)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)

# Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# 0.5902777777777778
# F1 score (micro-averaging): 0.5902777777777778
# F1 score (macro-averaging): 0.5714147286821706
# F1 score (weighted-averaging): 0.5917178079242034
# Confusion Matrix:
# [[36  1  7  0]
#  [ 2 20  6  2]
#  [ 1 26  7  1]
#  [ 3  9  1 22]]

# %%
#GradientBoostingClassifier
GBC=GradientBoostingClassifier()
GBC.fit(X_train,y_train)
print(GBC.score(X_test,y_test))
y_pred=GBC.predict(X_test)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)

# Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# 0.7430555555555556
# F1 score (micro-averaging): 0.7430555555555556
# F1 score (macro-averaging): 0.7041534199553068
# F1 score (weighted-averaging): 0.7319304378070101
# Confusion Matrix:
# [[44  0  0  0]
#  [ 1 10 18  1]
#  [ 1 13 19  2]
#  [ 1  0  0 34]]

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
param_grid={'n_estimators': [100,200,300],
           'max_depth':[None,5,10],
           'min_samples_split':[2,5,10],
        
           
}

# %%
#create the RandonForestClassifier()

RFC=RandomForestClassifier()

# %%
#perform grid search

grid_search=GridSearchCV(RFC,param_grid,cv=5)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 5, 10],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]})

# %%
#get the best parameters and the best score:

best_params=grid_search.best_params_
best_score=grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100}
# Best Score: 0.756521739130435

# %%
# Use the best model for prediction
final_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
final_model
# Out:
# RandomForestClassifier(min_samples_split=10)

# %%
# Calculate evaluation metrics
accuracy = final_model.score(X_test, y_test)
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("F1 score (micro-averaging):", f1_micro)
print("F1 score (macro-averaging):", f1_macro)
print("F1 score (weighted-averaging):", f1_weighted)

# Confusion Matrix
confusion_mat = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(confusion_mat)
# Out:
# Accuracy: 0.7430555555555556
# F1 score (micro-averaging): 0.7430555555555556
# F1 score (macro-averaging): 0.7050542620166517
# F1 score (weighted-averaging): 0.7294306390951092
# Confusion Matrix:
# [[44  0  0  0]
#  [ 1 14 12  3]
#  [ 1 15 15  4]
#  [ 1  0  0 34]]
